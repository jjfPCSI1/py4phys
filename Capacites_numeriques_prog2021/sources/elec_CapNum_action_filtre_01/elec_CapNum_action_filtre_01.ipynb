# %% [markdown]
# # Action d'un filtre sur un signal périodique, épisode I
#
# ## Problème à résoudre
#
# On vous fournit le spectre en amplitude d'un signal périodique en entrée avec la variable `freqs` qui contient les fréquences et la variable `FFT` qui contient la FFT, chacun sous forme de `np.array`.
#
# On fournit aussi une fonction `H` qui prend une fréquence en argument et renvoie la valeur complexe de la fonction de transfert à cette fréquence.
#
# Le but est de trouver la transformée de Fourier du signal de sortie en multipliant simplement la FFT d'entrée par le module de la fonction de transfert aux fréquences considérées.

# %%
# Modules utiles
import numpy as np
import matplotlib.pyplot as plt

# Les données, à savoir le spectre `FFT` 
# pour les fréquences `freqs` correspondantes
# ainsi que la fonction de transfert `H(f)` qui peut prendre des
# fréquences sous forme de np.array en argument
from donnees import *

# Calculez l'effet de la fonction de transfert sur le spectre

FFT_sortie = 'À compléter'
FFT_sortie = FFT * abs(H(freqs))

# Puis complétez le graphique ci-après pour y mettre aussi 
# le spectre du signal de sortie

plt.plot(freqs, FFT, label = "Signal d'entrée")
plt.plot(freqs, FFT_sortie)

plt.xlabel('Fréquence $f$')
plt.ylabel('Transformée de Fourier')
plt.legend()
plt.grid()
plt.xlim(0, max(freqs))
plt.ylim(ymin = 0)

# En réponse, on doit donner la FFT du signal de sortie

reponse = FFT_sortie
