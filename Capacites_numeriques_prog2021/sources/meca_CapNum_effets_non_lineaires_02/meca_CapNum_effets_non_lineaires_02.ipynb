# %% [markdown]
# # Effets non linéaires en mécanique, épisode II
#
# À présent que vous connaissez les outils (en particulier `odeint`) nécessaires pour intégrer une équadiff quelconque, essayons d'appliquer notre méthode au système suivant. Il s'agit d'un oscillateur dit de Landau
#
# ![oscillateur_landau.png](attachment:oscillateur_landau.png)
#
# pour lequel une masse peut se déplacer sans frottement selon l'axe horizontal et qui vérifie l'équation
# $$
# \frac{\mathrm{d}^2x}{\mathrm{d}t^2} + \frac{k}{m}\left(1 - \frac{\ell_0}{\sqrt{d^2 + x^2}}\right)x = 0
# $$
#
#
# ## Ce qui est fourni
#
# Le fichier de données définit les différentes constantes qui apparaissent dans cette équation:
# * $k$ la constante de raideur du ressort (variable `k`) ;
# * $\ell_0$ sa longueur à vide (variable `ell0`)
# * $d$ le décalage vertical du point d'attache du ressort (variable `d`)
# * $m$ la masse accrochée au ressort dont on regarde le déplacement (variable `m`)
# de même que les informations nécessaires pour l'intégration:
# * la variable `temps` contient les temps d'intégration demandés
# * la variable `positions_initiales` est une liste des valeurs initiales de $x$
#
# ## Ce qui est demandé
#
# Pour chacune des positions initiales, et en supposant que la masse est à chaque fois lancée sans vitesse initiale, il faut intégrer l'équation du mouvement pour trouver l'amplitude pic-à-pic résultante. C'est-à-dire que si vous avez récupéré dans la variable `X` les différentes valeurs de $x$ au cours du temps, on veut que soit mis dans la variable `reponse` (SANS accent) la liste des `max(X) - min(X)` qui correspondent à chaque  valeur initiale.
#
# ## En complément
#
# Faites une représentation graphique pour voir qu'au-delà d'une certaine position initiale, le comportement de l'oscillateur change du tout au tout.

# %%
# Les imports de tous les modules nécessaires
import numpy as np
import scipy as sp
import scipy.integrate
import matplotlib.pyplot as plt

# Import des données:
# * `k` pour la constante de raideur
# * `ell0` pour la longueur à vide
# * `d` pour le décalage du point de fixation
# * `m` pour la masse considérée
# * `temps` le np.array des temps sur lesquels faire l'intégration
# * `positions_initiales` la liste des valeurs initiales pour x 
#    en supposant les vitesses intialies nulles

from donnees import *

# Mettre ici vos boucles d'intégration




# Les réponses

reponse = "liste des amplitudes pic-à-pic, soit max - min pour chaque intégration"

print("Votre réponse: ", reponse)

# Faire ci-après la représentation graphique
